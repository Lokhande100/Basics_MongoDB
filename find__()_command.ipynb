# %% [markdown]
# <a href="https://colab.research.google.com/github/Lokhande10/Basics_MongoDB/blob/main/find__()_command.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Connecting terminal and run find command

# %% [markdown]
# ![image.png](data:image/png;base64,...)
