# %% [markdown]
# <a href="https://colab.research.google.com/github/Lokhande10/Basics_MongoDB/blob/main/Basics_MongoDB_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# What is MongoDB

# %% [markdown]
# 1.MongoDB database organizes documents in rows and columns.
# 2.MongoDB's database uses tables of related data.

# %%
# Did the logical size of the dataset and the number of operations increase in your cluster view similar to how it did in this image?

# %% [markdown]
# YES

# %%
# MongoDB Atlas

# %% [markdown]
# Replica Set - a few connected machines that store the same data to ensure that if something happens to one of the machines the data will remain intact. Comes from the word replicate - to copy something.
#
# Instance - a single machine locally or in the cloud, running a certain software, in our case it is the MongoDB database.
#
# Cluster - group of servers that store your data.

# %%
Created Project With sample database Deployment , Created Cluster.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# BSON

# %% [markdown]
# BSON simply stands for “Binary JSON,” and that’s exactly what it was invented to be. BSON’s binary structure encodes type and length information, which allows it to be parsed much more quickly.

# %%
# JSON VS BSON

# %% [markdown]
# MongoDB stores data in BSON, and you can then view it JSON.
#
# BSON is faster to parse and lighter to store than JSON.
#
# JSON supports fewer data types than BSON.

# %%
#SRV -- create secure connection

# %%
# Data Explorer - Collections- with sample dataset (8 Database with 21 collections)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
{"start station name" : "Howard St & Centre St", "birth year" : 1961}

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
My Copy paste was not rightly done here.. but my query was right.

# %%
#Installed mongosh
#connected database

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#now connect to Sample training database and check collections

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# _id is the unique document identifier in mongo db
